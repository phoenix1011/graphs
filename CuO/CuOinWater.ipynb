# %% [markdown]
# **Transmission sprectra of CuO/water**

# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline

# %%
x = numpy.linspace(190,1100,911)

y1 = []
y2 = []
y3 = []
y4 = []
y5 = []

# %% [markdown]
# Volume fraction = **0.00025337**
#
# Color = **Blue**

# %%
file_name = "CuO_0.8.txt"
with open(file_name, 'r') as infile:
    for line in infile:
        y1.append(float(line))

# %% [markdown]
# Volume fraction = **0.0005384**
#
# Color = **Green**

# %%
file_name = "CuO_1.7.txt"

# %%
with open(file_name, 'r') as infile:
    for line in infile:
        y2.append(float(line))

# %% [markdown]
# Volume fraction = **0.00101346**
#
# Color = **Red**

# %%
file_name = "CuO_31.5.txt"

# %%
with open(file_name, 'r') as infile:
    for line in infile:
        y4.append(float(line))

# %% [markdown]
# Volume fraction = **0.00498812**
#
# Color = **Cyan**

# %%
file_name = "CuO_3.2.txt"
with open(file_name, 'r') as infile:
    for line in infile:
        y5.append(float(line))

# %%
pyplot.figure(figsize=(10,10))
pyplot.ylim(0,100)
pyplot.tick_params(axis='both', labelsize=16)
pyplot.xlabel('wavelength (nm)', fontsize=16)
pyplot.ylabel('Transmittance (%)', fontsize=16)
pyplot.plot(x, y1, 'b-', x, y2, 'g-', x, y4, 'r-', x, y5, 'c-');
pyplot.legend(['0.00025337 v%', '0.00053840 v%', '0.00101346 v%', '0.00498812 v%'], fontsize=16)
pyplot.title('CuO/Water', fontsize=16)
